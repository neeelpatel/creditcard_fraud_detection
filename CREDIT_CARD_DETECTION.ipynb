# %% [markdown]
# # Credit Card Detection

# %%
#import dataset
import pandas as pd
import os
os.chdir('F:\\neel\\fingertips\\machine learning\\project')
data=pd.read_csv("creditcard.csv")

# %%
data.head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
# 3  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321 -1.175575  0.647376
# 4 -0.270533  0.817739  ... -0.009431  0.798278 -0.137458  0.141267 -0.206010
#
# ...

# %%
#Describe data and check information of data
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 284807 entries, 0 to 284806
# Data columns (total 31 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   Time    284807 non-null  float64
#  1   V1      284807 non-null  float64
#  2   V2      284807 non-null  float64
#  3   V3      284807 non-null  float64
#  4   V4      284807 non-null  float64
#  5   V5      284807 non-null  float64
#  6   V6      284807 non-null  float64
#  7   V7      284807 non-null  float64
#  8   V8      284807 non-null  float64
#  9   V9      284807 non-null  float64
#  10  V10     284807 non-null  float64
#  11  V11     284807 non-null  float64
#  12  V12     284807 non-null  float64
#  13  V13     284807 non-null  float64
#  14  V14     284807 non-null  float64
#  15  V15     284807 non-null  float64
#  16  V16     284807 non-null  float64
#  17  V17     284807 non-null  float64
#  18  V18     284807 non-null  float64
#  19  V19     284807 non-null  float64
# ...

# %%
data.describe()
# Out:
#                 Time            V1            V2            V3            V4  \
# count  284807.000000  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean    94813.859575  3.918649e-15  5.682686e-16 -8.761736e-15  2.811118e-15
# std     47488.145955  1.958696e+00  1.651309e+00  1.516255e+00  1.415869e+00
# min         0.000000 -5.640751e+01 -7.271573e+01 -4.832559e+01 -5.683171e+00
# 25%     54201.500000 -9.203734e-01 -5.985499e-01 -8.903648e-01 -8.486401e-01
# 50%     84692.000000  1.810880e-02  6.548556e-02  1.798463e-01 -1.984653e-02
# 75%    139320.500000  1.315642e+00  8.037239e-01  1.027196e+00  7.433413e-01
# max    172792.000000  2.454930e+00  2.205773e+01  9.382558e+00  1.687534e+01
#
#                  V5            V6            V7            V8            V9  \
# count  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean  -1.552103e-15  2.040130e-15 -1.698953e-15 -1.893285e-16 -3.147640e-15
# ...

# %%
#checking for null value
data.isnull().sum()
# Out:
# Time      0
# V1        0
# V2        0
# V3        0
# V4        0
# V5        0
# V6        0
# V7        0
# V8        0
# V9        0
# V10       0
# V11       0
# V12       0
# V13       0
# V14       0
# V15       0
# V16       0
# V17       0
# V18       0
# V19       0
# V20       0
# V21       0
# V22       0
# V23       0
# V24       0
# V25       0
# V26       0
# V27       0
# V28       0
# Amount    0
# Class     0
# dtype: int64

# %%
#check shape of data
data.shape
# Out:
# (284807, 31)

# %%
#check class feature and make value count for it
data['Class'].value_counts()
# Out:
# 0    284315
# 1       492
# Name: Class, dtype: int64

# %% [markdown]
# we can say that over data is highly biased towards legit transactions  because out of 284807 record there are  284315 record belong to legit transcation and only 492 record are fraudulent transcation.

# %%
# separating the data for analysis
legit = data[data.Class==0]
fraud = data[data.Class==1]

# %%
legit.shape
# Out:
# (284315, 31)

# %%
fraud.shape
# Out:
# (492, 31)

# %%
#stastical meausure of data
legit.Amount.describe()
# Out:
# count    284315.000000
# mean         88.291022
# std         250.105092
# min           0.000000
# 25%           5.650000
# 50%          22.000000
# 75%          77.050000
# max       25691.160000
# Name: Amount, dtype: float64

# %%
fraud.Amount.describe()
# Out:
# count     492.000000
# mean      122.211321
# std       256.683288
# min         0.000000
# 25%         1.000000
# 50%         9.250000
# 75%       105.890000
# max      2125.870000
# Name: Amount, dtype: float64

# %%
#compare value for both transcation
data.groupby('Class').mean()
# Out:
#                Time        V1        V2        V3        V4        V5  \
# Class
# 0      94838.202258  0.008258 -0.006271  0.012171 -0.007860  0.005453
# 1      80746.806911 -4.771948  3.623778 -7.033281  4.542029 -3.151225
#
#              V6        V7        V8        V9  ...       V20       V21  \
# Class                                          ...
# 0      0.002419  0.009637 -0.000987  0.004467  ... -0.000644 -0.001235
# 1     -1.397737 -5.568731  0.570636 -2.581123  ...  0.372319  0.713588
#
#             V22       V23       V24       V25       V26       V27       V28  \
# Class
# 0     -0.000024  0.000070  0.000182 -0.000072 -0.000089 -0.000295 -0.000131
# 1      0.014049 -0.040308 -0.105130  0.041449  0.051648  0.170575  0.075667
#
#            Amount
# Class
# 0       88.291022
# 1      122.211321
#
# [2 rows x 30 columns]

# %% [markdown]
# Our data is imbalanced so we take the sample of legit data

# %%
legit = legit.sample(n=492)

# %%
print(legit.shape)
print(fraud.shape)
# Out:
# (492, 31)
# (492, 31)

# %%
#combine both dataset
final_dataset = pd.concat([legit,fraud],axis=0)

# %%
final_dataset.shape
# Out:
# (984, 31)

# %%
#check value count for class
final_dataset['Class'].value_counts()
# Out:
# 0    492
# 1    492
# Name: Class, dtype: int64

# %%
final_dataset.groupby('Class').mean()
# Out:
#                Time        V1        V2        V3        V4        V5  \
# Class
# 0      96749.540650  0.061495 -0.021265 -0.041941  0.003707  0.034008
# 1      80746.806911 -4.771948  3.623778 -7.033281  4.542029 -3.151225
#
#              V6        V7        V8        V9  ...       V20       V21  \
# Class                                          ...
# 0      0.020739 -0.002489  0.024612 -0.002696  ... -0.005660  0.038092
# 1     -1.397737 -5.568731  0.570636 -2.581123  ...  0.372319  0.713588
#
#             V22       V23       V24       V25       V26       V27       V28  \
# Class
# 0     -0.055382 -0.035616  0.014738 -0.004338 -0.015648 -0.008001  0.001111
# 1      0.014049 -0.040308 -0.105130  0.041449  0.051648  0.170575  0.075667
#
#            Amount
# Class
# 0       93.996585
# 1      122.211321
#
# [2 rows x 30 columns]

# %%
# dependent(target) and independent variable
x=final_dataset.drop('Class',axis=1)

# %%
y=final_dataset.Class

# %%
#split the data into train test split
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=.2,random_state=10)

# %%
print(x_train.shape)
print(x_test.shape)
# Out:
# (787, 30)
# (197, 30)

# %% [markdown]
# Model training
# Logistic regression

# %%
from sklearn.linear_model import LogisticRegression
model=LogisticRegression()

# %%
model.fit(x_train,y_train)
# Out:
# LogisticRegression()

# %% [markdown]
# # Model Evaluation

# %%
from sklearn.metrics import accuracy_score,confusion_matrix
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#accuracy check on training set
x_train_prediction=model.predict(x_train)
accuracy_score(x_train_prediction,y_train)
# Out:
# 0.9504447268106735

# %%
#accuracy check on test set
y_predict = model.predict(x_test)
accuracy_score(y_test,y_predict)
# Out:
# 0.9543147208121827

# %%
matrix = confusion_matrix(y_test,y_predict)
matrix
# Out:
# array([[98,  4],
#        [ 5, 90]], dtype=int64)

# %%
plt.figure(figsize=(12,6))
sns.heatmap(matrix,annot=True,fmt='g')
plt.xlabel('Predicted ')
plt.ylabel('actual')
# Out:
# Text(87.0, 0.5, 'actual')

# %%
from sklearn.metrics import classification_report,accuracy_score
from sklearn.ensemble import IsolationForest
from sklearn.neighbors import LocalOutlierFactor

# %%
data
# Out:
#             Time         V1         V2        V3        V4        V5  \
# 0            0.0  -1.359807  -0.072781  2.536347  1.378155 -0.338321
# 1            0.0   1.191857   0.266151  0.166480  0.448154  0.060018
# 2            1.0  -1.358354  -1.340163  1.773209  0.379780 -0.503198
# 3            1.0  -0.966272  -0.185226  1.792993 -0.863291 -0.010309
# 4            2.0  -1.158233   0.877737  1.548718  0.403034 -0.407193
# ...          ...        ...        ...       ...       ...       ...
# 284802  172786.0 -11.881118  10.071785 -9.834783 -2.066656 -5.364473
# 284803  172787.0  -0.732789  -0.055080  2.035030 -0.738589  0.868229
# 284804  172788.0   1.919565  -0.301254 -3.249640 -0.557828  2.630515
# 284805  172788.0  -0.240440   0.530483  0.702510  0.689799 -0.377961
# 284806  172792.0  -0.533413  -0.189733  0.703337 -0.506271 -0.012546
#
#               V6        V7        V8        V9  ...       V21       V22  \
# ...

# %%
data.isnull().values.any()
# Out:
# False

# %%
import matplotlib.pyplot as plt
counts = pd.value_counts(data['Class'], sort = True)

counts.plot(kind = 'bar', rot=0)
plt.xlabel("Class")

plt.ylabel("Frequency")
# Out:
# Text(0, 0.5, 'Frequency')

# %%
#fraudatlent and normal data
normal = data[data['Class']==0]
fraud=data[data['Class']==1]

# %%
fraud.shape
# Out:
# (492, 31)

# %%
normal.shape
# Out:
# (284315, 31)

# %%
fraud.Amount.describe()
# Out:
# count     492.000000
# mean      122.211321
# std       256.683288
# min         0.000000
# 25%         1.000000
# 50%         9.250000
# 75%       105.890000
# max      2125.870000
# Name: Amount, dtype: float64

# %%
normal.Amount.describe()
# Out:
# count    284315.000000
# mean         88.291022
# std         250.105092
# min           0.000000
# 25%           5.650000
# 50%          22.000000
# 75%          77.050000
# max       25691.160000
# Name: Amount, dtype: float64

# %%
import seaborn as sns
sns.histplot(fraud.Amount,bins=50)
# Out:
# <AxesSubplot:xlabel='Amount', ylabel='Count'>

# %%
sns.histplot(normal.Amount,bins=50)
# Out:
# <AxesSubplot:xlabel='Amount', ylabel='Count'>

# %%
sns.scatterplot(data=fraud, x="Time", y="Amount")
# Out:
# <AxesSubplot:xlabel='Time', ylabel='Amount'>

# %%
sns.scatterplot(data=normal, x="Time", y="Amount")
# Out:
# <AxesSubplot:xlabel='Time', ylabel='Amount'>

# %%
#take a sample of dataset

# %%
data1=data.sample(frac=0.1,random_state=1)
print(data1.shape)
print(data.shape)
# Out:
# (28481, 31)
# (284807, 31)

# %%
fraud = data1[data1['Class']==1]
normal=data1[data1['Class']==0]

# %%
print(fraud.shape)
print(normal.shape)
# Out:
# (49, 31)
# (28432, 31)

# %%
#check corelation between different feature
corr = data1.corr()
plt.figure(figsize=(20,20))
sns.heatmap(corr,annot=True)
# Out:
# <AxesSubplot:>

# %%
#create dependent and independentvariable
x=data1.drop("Class",axis=1)
x
# Out:
#             Time        V1        V2        V3        V4        V5        V6  \
# 169876  119907.0 -0.611712 -0.769705 -0.149759 -0.224877  2.028577 -2.019887
# 127467   78340.0 -0.814682  1.319219  1.329415  0.027273 -0.284871 -0.653985
# 137900   82382.0 -0.318193  1.118618  0.969864 -0.127052  0.569563 -0.532484
# 21513    31717.0 -1.328271  1.018378  1.775426 -1.574193 -0.117696 -0.457733
# 134700   80923.0  1.276712  0.617120 -0.578014  0.879173  0.061706 -1.472002
# ...          ...       ...       ...       ...       ...       ...       ...
# 2032      1574.0 -0.615776  0.654356  2.618793  0.857434 -0.487340  0.593957
# 240932  150813.0 -3.517229  3.326821 -3.590262  0.674769 -0.679266 -0.469516
# 3701      3169.0 -0.315540  1.054303  1.484711  1.138262  0.394713 -0.168883
# 153365   98752.0 -3.580417  4.100916 -2.577720 -1.476718 -0.006201 -2.008418
# 97365    66187.0  1.213349  0.227172 -0.886860  1.345683  2.254592  3.788565
#
# ...

# %%
y=data1.Class
y
# Out:
# 169876    0
# 127467    0
# 137900    0
# 21513     0
# 134700    0
#          ..
# 2032      0
# 240932    0
# 3701      0
# 153365    0
# 97365     0
# Name: Class, Length: 28481, dtype: int64

# %%
#model
classifier = {
    "IsolationForest ":IsolationForest(n_estimators=100,verbose=0,max_samples=len(x)),
    "local Outlier Factor":LocalOutlierFactor(n_neighbors=20)
    
}

# %%
classifier.items()
# Out:
# dict_items([('IsolationForest ', IsolationForest(max_samples=28481)), ('local Outlier Factor', LocalOutlierFactor())])

# %%
for i, (clf_name,clf) in enumerate(classifier.items()):
    if clf_name == "IsolationForest":
        y_pred = clf.fit_predict(x)
    else:
        clf.fit(x)
        y_pred = clf.predict(x)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_3400/2560941157.py in <module>
#       4     else:
#       5         clf.fit(x)
# ----> 6         y_pred = clf.predict(x)
#       7
#       8
#
# ~\anaconda3\lib\site-packages\sklearn\neighbors\_lof.py in predict(self)
#     323                    'novelty=True if you want to use LOF for novelty detection '
#     324                    'and predict on new unseen data.')
# --> 325             raise AttributeError(msg)
#     326
#     327         return self._predict
#
# AttributeError: predict is not available when novelty=False, use fit_predict if you want to predict on training data. Use novelty=True if you want to use LOF for novelty detection and predict on new unseen data.

# %%
for i, (clf_name,clf) in enumerate(classifier.items()):
    #Fit the data and tag outliers
    if clf_name == "Local Outlier Factor":
        y_pred = clf.fit_predict(x)
        scores_prediction = clf.negative_outlier_factor_
    else:    
        clf.fit(x)
        scores_prediction = clf.decision_function(x)
        y_pred = clf.predict(x)
    #Reshape the prediction values to 0 for Valid transactions , 1 for Fraud transactions
    y_pred[y_pred == 1] = 0
    y_pred[y_pred == -1] = 1
    n_errors = (y_pred != y).sum()
    # Run Classification Metrics
    print("{}: {}".format(clf_name,n_errors))
    print("Accuracy Score :")
    print(accuracy_score(y,y_pred))
    print("Classification Report :")
    print(classification_report(y,y_pred))
